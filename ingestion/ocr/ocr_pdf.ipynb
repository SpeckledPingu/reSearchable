# %%
import pandas as pd
import numpy as np
from doctr.io import DocumentFile
from doctr.models import ocr_predictor

# %%
pdf = "/home/jameslittiebrant/DataspellProjects/hybridSearch/data/pdfs/trump-indictment.pdf"

# %%
model = ocr_predictor(pretrained=True)
# PDF
doc = DocumentFile.from_pdf(pdf)
# Analyze

# %%
doc

# %%
result = model(doc)

# %%
result
# Out:
# Document(
#   (pages): [
#     Page(
#       dimensions=(1584, 1224)
#       (blocks): [
#         Block(
#           (lines): [Line(
#             (words): [
#               Word(value='Case', confidence=1.0),
#               Word(value='9:23-Cr-80101-AMC', confidence=0.78),
#               Word(value='Document', confidence=1.0),
#               Word(value='3', confidence=1.0),
#               Word(value='Entered', confidence=0.74),
#               Word(value='on', confidence=1.0),
#               Word(value='FLSD', confidence=0.89),
#               Word(value='Docket', confidence=1.0),
#               Word(value='06/08/2023', confidence=0.85),
#               Word(value='Pags', confidence=0.36),
#               Word(value='dy', confidence=0.68),
#               Word(value='of', confidence=0.99),
#               Word(value='Mc', confidence=0.95),
#               Word(value='D.C', confidence=0.91),
#             ]
#           )]
#           (artefacts): []
#         ),
# ...

# %%
result.synthesize?

# %%
synthesized = result.synthesize()

# %%
result.export()
# Out:
# {'pages': [{'page_idx': 0,
#    'dimensions': (1584, 1224),
#    'orientation': {'value': None, 'confidence': None},
#    'language': {'value': None, 'confidence': None},
#    'blocks': [{'geometry': ((0.0947265625, 0.013671875),
#       (0.97265625, 0.0400390625)),
#      'lines': [{'geometry': ((0.0947265625, 0.013671875),
#         (0.97265625, 0.0400390625)),
#        'words': [{'value': 'Case',
#          'confidence': 0.9994460940361023,
#          'geometry': ((0.0947265625, 0.0166015625),
#           (0.142578125, 0.0322265625))},
#         {'value': '9:23-Cr-80101-AMC',
#          'confidence': 0.7783722877502441,
#          'geometry': ((0.146484375, 0.0166015625),
#           (0.3193359375, 0.0302734375))},
#         {'value': 'Document',
#          'confidence': 0.9997949600219727,
#          'geometry': ((0.333984375, 0.0166015625), (0.42578125, 0.03125))},
#         {'value': '3',
#          'confidence': 0.9999790191650391,
# ...
